# %% [markdown]
# Notes from the book **C Programming by Harry H. Chaudhary**

# %% [markdown]
# #### Assembler Vs. Compiler
#
# |Assembler|Compiler|
# |---------|--------|
# |Translates the mnemonic code such as PRN, ADD, and SUB etc. to machine language code.| It translates the high level language to assembly language.|
# |The program, which executes using assembler, executes faster, because it directly converts the source code in machine language.| It takes time to execute a program, because it first translates the source code into another compiler's language and then using assembler converts it into machine language.|

# %% [markdown]
# #### Compiler Vs. Interpreter
#
# |Compiler | Interpreter |
# |---------|-------------|
# |Compiler translates the entire high level language program into the machine language program at once before executing. This optimizes the use of machine language instructions in the translated program. Therefore normally compiled programs run faster than interpreted programs. The original high level language program is called as _source program_. The compiled program i.e. machine language program generated by the compiler after translation is called object program. | The interpreter translates the program written in high level languages into machine language at the time of executing that program, instructions by instructions. That is, it reads the first instruction written in the program and converts that into equivalent machine language instructions. Then the CPU watches those machine language instructions. After that, the Interpreter reads and translates the next instruction and so on.|
# |Compiler takes _entire_ program as input.| Interpreter takes _single_ instructions as input|
# |Object code is permanently saved for future use.|No object code is saved for future use.
# |Non time consuming translation method.| Time consuming translation method.|
# |It required large space in the computer.| Interpreter are easy to write and do not require large memory space.|
# |Speed of a compiler is very fast.|Speed is very slow.|
# |Any change in source program after the compilation requires recompiling of entire code.| Any change in source program during the translation does not require's retranslation of entire code.|
# |Intermediate Object code is generated.| No intermediate Object Code is generated|
# |Conditional control statements are executed faster.|Conditional Control statements are executed slower.
# |Memory requirement is more (since object code is generated)|Memory requirement is less.|
# |Errors are displayed after entire program is checked.|Errors are displayed for every instruction interpreted.|
# |Example: C Compiler.|Example: BASIC|

# %% [markdown]
# ### Fill in the blanks:
#
# 1. Dennis Ritchie is the creator of C language. It was developed at **American Telegraph & Telecommunication (AT & T) Bell Laboratories** in **1972** year.
#
# 2. **UNIX** operating system is developed in C.
#
# 3. **Basic Combined Programming Language, (B)** can be stated the ancestor of C.
#
# 4. C language is translated into machine code using a **compiler**.
#
# 5. C can be used with **MS-DOS**, **LINUX**, and **Windows** operating systems.
